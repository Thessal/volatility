# %%
import pandas as pd 
from volatiltyestimation import PRV 
df = pd.read_csv("./mid_1s/08-19_1s.csv.zst")

# %%
x = df["BTC-USDT_bitfinex"].dropna().values
model = PRV
vol_estimator = model(x)
vol_estimator.fit()
# Out:
# window = 1	 information amount = 1.79e+05	 prv/rv = 1.00e+00	 rv = 2.75e-07	 prv = 2.75e-07 	 score = 1.54e-12
# window = 3	 information amount = 9.03e+04	 prv/rv = 6.47e-01	 rv = 2.75e-07	 prv = 1.78e-07 	 score = 1.97e-12
# window = 5	 information amount = 6.57e+04	 prv/rv = 1.15e+00	 rv = 1.23e-07	 prv = 1.42e-07 	 score = 2.16e-12
# window = 7	 information amount = 6.71e+04	 prv/rv = 1.53e+00	 rv = 7.08e-08	 prv = 1.08e-07 	 score = 1.62e-12
# window = 9	 information amount = 6.06e+04	 prv/rv = 1.97e+00	 rv = 4.45e-08	 prv = 8.78e-08 	 score = 1.45e-12
# window = 11	 information amount = 6.91e+04	 prv/rv = 2.70e+00	 rv = 2.94e-08	 prv = 7.91e-08 	 score = 1.15e-12
# window = 13	 information amount = 6.75e+04	 prv/rv = 3.75e+00	 rv = 2.07e-08	 prv = 7.75e-08 	 score = 1.15e-12
# window = 15	 information amount = 1.15e+05	 prv/rv = 4.95e+00	 rv = 1.61e-08	 prv = 7.98e-08 	 score = 6.91e-13
# window = 17	 information amount = 1.34e+05	 prv/rv = 6.19e+00	 rv = 1.35e-08	 prv = 8.33e-08 	 score = 6.22e-13
# window = 19	 information amount = 1.44e+05	 prv/rv = 7.28e+00	 rv = 1.19e-08	 prv = 8.70e-08 	 score = 6.04e-13
# {'window': 5}

# %%
pd.Series(vol_estimator.scores).plot(ylabel="PRV / information score", xlabel="window length", title="08-19_1s.csv.zst BTCUSDT bitfinex \noptimal window search")
import matplotlib.pyplot as plt 
plt.axvline(5, color="red")
